# %%
import pandas as pd
df=pd.read_csv("G:\SampleData.csv")
df
#df.shape #gives the count of rows and columns
df.head() #top 5 rows
df.tail() #bottom 5 rows
df.columns # columns in the csv/table
df[['OrderDate','Region']] #OR df.OrderDate to access individual columns
df.head()
df.describe() #to get the analysis of that table
df[df.Units==df['Units'].max()] # writing condition to execute the required result
df[['Region','Rep','Total']][df['Total']==df['Total'].max()]

# %%
df.set_index('OrderDate',inplace=True) #to change the inex to OrderDate and replaceing the original data frame
df.reset_index(inplace=True) #reset the index to get the original dataframe
df
# Out:
#    OrderDate   Region       Rep     Item          Units Unit Cost     Total
# 0   01-06-18     East     Jones   Pencil             95      1.99    189.05
# 1    1-23-18  Central    Kivell   Binder             50     19.99     999.5
# 2   02-09-18  Central   Jardine   Pencil             36      4.99    179.64
# 3    2-26-18  Central      Gill      Pen             27     19.99    539.73
# 4    3-15-18     West   Sorvino   Pencil             56      2.99    167.44
# 5   04-01-18     East     Jones   Binder             60      4.99     299.4
# 6    4-18-18  Central   Andrews   Pencil             75      1.99    149.25
# 7   05-05-18  Central   Jardine   Pencil             90      4.99     449.1
# 8    5-22-18     West  Thompson   Pencil             32      1.99     63.68
# 9   06-08-18     East     Jones   Binder             60      8.99     539.4
# 10   6-25-18  Central    Morgan   Pencil             90      4.99     449.1
# ...

# %%
df1=pd.read_csv("G:\SampleData.csv",skiprows=1,nrows=3,header=None,names=['orderdate','region','representative','item','units','cost of unit','Final total'])
#changing the header name with different names - "nrows" means to read those many number of rows
df1
# Out:
#   orderdate   region representative    item  units  cost of unit  Final total
# 0    1-6-18     East          Jones  Pencil     95          1.99       189.05
# 1   1-23-18  Central         Kivell  Binder     50         19.99       999.50
# 2    2-9-18  Central        Jardine  Pencil     36          4.99       179.64

# %%
df2=pd.read_csv("G:\SampleData.csv",na_values=["not available","n.a"],nrows=4)
df2
# Out:
#   OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0  01-06-18     East    Jones  Pencil     95       1.99  189.05
# 1   1-23-18  Central   Kivell  Binder     50      19.99  999.50
# 2  02-09-18  Central  Jardine  Pencil     36       4.99  179.64
# 3   2-26-18  Central     Gill     Pen     27      19.99  539.73

# %%
#this is to use "convert" function and replace the words with other words 
def convert_Units(cell):
      if cell=="not available":
        return 0
      return cell
def convert_Unit_Cost(cell):
    if cell=="n.a":
        return 0
    return cell
df3=pd.read_csv("G:\SampleData.csv",converters = {
    'Units':convert_Units,
    'Unit Cost':convert_Unit_Cost
})
df3.head()
# Out:
#   OrderDate   Region      Rep    Item Units Unit Cost   Total
# 0  01-06-18     East    Jones  Pencil    95      1.99  189.05
# 1   1-23-18  Central   Kivell  Binder    50     19.99   999.5
# 2  02-09-18  Central  Jardine  Pencil    36      4.99  179.64
# 3   2-26-18  Central     Gill     Pen    27     19.99  539.73
# 4   3-15-18     West  Sorvino  Pencil    56      2.99  167.44

# %%
#changing the date string into  and using fillna methods
df4=pd.read_csv("G:\SampleData.csv",nrows=40,parse_dates=['OrderDate'])
new_df4=df4.fillna(method="bfill") #dropna(threshold=1,how='all')
new_df4.head(10)
# Out:
#    OrderDate   Region       Rep    Item Units Unit Cost   Total
# 0 2018-01-06     East     Jones  Pencil    95      1.99  189.05
# 1 2018-01-23  Central    Kivell  Binder    50     19.99   999.5
# 2 2018-02-09  Central   Jardine  Pencil    36      4.99  179.64
# 3 2018-02-26  Central      Gill     Pen    27     19.99  539.73
# 4 2018-03-15     West   Sorvino  Pencil    56      2.99  167.44
# 5 2018-04-01     East     Jones  Binder    60      4.99   299.4
# 6 2018-04-18  Central   Andrews  Pencil    75      1.99  149.25
# 7 2018-05-05  Central   Jardine  Pencil    90      4.99   449.1
# 8 2018-05-22     West  Thompson  Pencil    32      1.99   63.68
# 9 2018-06-08     East     Jones  Binder    60      8.99   539.4

# %%
#replace function
import numpy as np
df5=pd.read_csv("G:\SampleData.csv",na_values=['not available','n.a'])
new_df2=df5.dropna(thresh=1)
#new_df23=new_df2.replace('1,619.19',np.NaN)   #replace type 1
#replace type with dictionaries
#new_df23=new_df2.replace({                 
#    "Item":"Pen",
 #   "Region":"West"
#},np.NaN)
#replace with regular expression
new_df2.head(10).replace({
    'Region':'[A-Z]'},'',regex=True)
# Out:
#   OrderDate  Region       Rep    Item  Units  Unit Cost   Total
# 0  01-06-18     ast     Jones  Pencil   95.0       1.99  189.05
# 1   1-23-18  entral    Kivell  Binder   50.0      19.99   999.5
# 2  02-09-18  entral   Jardine  Pencil   36.0       4.99  179.64
# 3   2-26-18  entral      Gill     Pen   27.0      19.99  539.73
# 4   3-15-18     est   Sorvino  Pencil   56.0       2.99  167.44
# 5  04-01-18     ast     Jones  Binder   60.0       4.99   299.4
# 6   4-18-18  entral   Andrews  Pencil   75.0       1.99  149.25
# 7  05-05-18  entral   Jardine  Pencil   90.0       4.99   449.1
# 8   5-22-18     est  Thompson  Pencil   32.0       1.99   63.68
# 9  06-08-18     ast     Jones  Binder   60.0       8.99   539.4
